# %%
import os

# %%
# check the folder in which we have terms and condition document which will become input to vector databse creation
os.listdir("./T_and_Cs/")
# Out:
# ['card-member-agreement.pdf']

# %%
# importing important modules required for vector databse creation
from vector_db.vector_db_create import create_vector_embeddings_and_save
from vector_db.vector_db_load import load_vector_db

# %%
# calling function which takes document as input and store the faiss index and id_to_chunk mapping in local folder
index_path, data_path = create_vector_embeddings_and_save(
    pdf_path="./T_and_Cs/card-member-agreement.pdf",
    index_path="./vector_db/output/axis_cc_terms.index",
    data_path="./vector_db/output/idx_to_data.pkl",
    device="cpu"
)
# Out:
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# FAISS index saved. Total vectors: 111

# %%
# once executed you will find stored indexes and object in the folder below
os.listdir("./vector_db/output/")
# Out:
# ['axis_cc_terms.index', 'idx_to_data.pkl']
